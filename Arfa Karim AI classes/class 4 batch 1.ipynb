# %% [markdown]
# # Functions

# %%
def show():
    print("In the show function")

# %%
show()
# Out:
# In the show function

# %%
def sum(num1, num2):
    print(num1+ num2)

# %%
sum(4, 6)
# Out:
# 10

# %%
def checkpass(marks):
    if (marks>=50):
        print("You are pass")
    else:
        print("You are fail")

# %%
a=int(input("Enter marks: "))
checkpass(a)
# Out:
# Enter marks:  12
# You are fail

# %% [markdown]
# # Matplotlib charts

# %%
#!pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
name= ["ali", "ahmed", "eisha"]
marks=[78,65,67]

# %%
plt.scatter(name, marks)

# %%
plt.plot(name, marks, color="yellow")

# %%
plt.bar(name, marks, color="green")

plt.xlabel("Name of Students")
plt.ylabel("Marks of students")
plt.title("Class Data")
plt.show()

# %%
import numpy as np
points=np.linspace(1,10, 100)

# %%
sine_values=np.sin(points)

# %%
plt.scatter(points, sine_values)

# %%
plt.plot(points, sine_values)

# %%
import pandas as pd
data= pd.read_excel("D:\\test.xlsx")

# %%
data.head()
# Out:
#       name  marks   age
# 0      Ali   45.0  23.0
# 1    Ahmed  100.0  12.0
# 2   Rameen   34.0  34.0
# 3   Ayesha   23.0   0.0
# 4  Khadija    NaN  42.0

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        name  marks   age
# 0       Ali   45.0  23.0
# 1     Ahmed  100.0  12.0
# 2    Rameen   34.0  34.0
# 3    Ayesha   23.0   0.0
# 6     rehan   98.0  12.0
# 7    daneen   22.5  34.0
# 8   zawiyar   34.0   2.0
# 9  abdullah   23.0  21.0

# %%
plt.bar(data["name"], data["marks"])
# Out:
# <BarContainer object of 8 artists>

# %%
x= data["name"]
y=data["marks"]

# %%
plt.scatter(x, y)

# %%
plt.pie(y, labels=x, autopct= "%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1c38f378140>,
# ...
#  [Text(1.0245540757447873, 0.40036101942465024, 'Ali'),
#   Text(-0.002276579786388327, 1.0999976441722392, 'Ahmed'),
#   Text(-0.9859299445454005, 0.48779313694301174, 'Rameen'),
#   Text(-1.09991519445726, -0.013658879970491844, 'Ayesha'),
#   Text(-0.5812369194529367, -0.933897019732294, 'rehan'),
#   Text(0.4693459216077659, -0.9948439103046051, 'daneen'),
#   Text(0.8674656332069256, -0.6763899579420941, 'zawiyar'),
#   Text(1.0801216145348795, -0.20817612210473377, 'abdullah')],
#  [Text(0.5588476776789748, 0.21837873786799103, '11.9%'),
#   Text(-0.001241770792575451, 0.5999987150030396, '26.4%'),
#   Text(-0.5377799697520366, 0.26606898378709726, '9.0%'),
#   Text(-0.5999537424312327, -0.007450298165722823, '6.1%'),
#   Text(-0.31703831970160173, -0.509398374399433, '25.8%'),
#   Text(0.25600686633150865, -0.5426421328934209, '5.9%'),
#   Text(0.473163072658323, -0.368939977059324, '9.0%'),
# ...

# %%
plt.barh(y, x)
# Out:
# <BarContainer object of 8 artists>

# %%
plt.plot(x, y, color="purple", marker="o", linestyle="--")

# %%
df=pd.read_csv("C:\\Users\\U$ER\\Desktop\\AKTI AI classes\\datasets\\Diwali Sales Data.csv", encoding="unicode_escape")

# %%
df.head(3)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
#
#             State      Zone  Occupation Product_Category  Orders   Amount  \
# 0     Maharashtra   Western  Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern        Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central  Automobile             Auto       3  23924.0
#
#    Status  unnamed1
# 0     NaN       NaN
# 1     NaN       NaN
# 2     NaN       NaN

# %%
df.drop(["Status", "unnamed1"], inplace=True, axis=1)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
df.dropna(inplace=True)

# %%
#!pip install seaborn
import seaborn as sns

# %%
sns.countplot(data=df, x="Age Group")
# Out:
# <Axes: xlabel='Age Group', ylabel='count'>

# %%
sns.countplot(data=df, x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df, x="Gender", hue="Marital_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df, x="Occupation")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.set(rc={"figure.figsize": (30,10)})

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
sns.countplot(data=df, x="Product_Category")
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>
